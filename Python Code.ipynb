# %%
import pandas as pd
import numpy as np

# %%
station = pd.read_csv('example_sprit_cut_station.csv', delimiter = ';')
prices = pd.read_csv('example_sprit_cut_prices.csv', delimiter = ';')

# %%
prices.head()

print(prices.shape)

prices = prices.drop_duplicates()

print(prices.shape)
# Out:
# (2189526, 6)
# (1094763, 6)

# %%
null_columns=station.columns[station.isnull().any()]
station[null_columns].isnull().sum()
# Out:
# BRAND            22
# STREET            4
# HOUSE_NUMBER    150
# POST_CODE         4
# PLACE             4
# dtype: int64

# %%
null_columns=prices.columns[prices.isnull().any()]
prices[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094763 entries, 0 to 2177846
# Data columns (total 6 columns):
# STID            1094763 non-null object
# E5              1094763 non-null int64
# E10             1094763 non-null int64
# DIESEL          1094763 non-null int64
# DATE_CHANGED    1094763 non-null object
# CHANGED         1094763 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 58.5+ MB

# %%
prices
# Out:
#                                          STID    E5   E10  DIESEL  \
# 0        01bf5a06-4248-43a5-9524-56123fa3ab2f  1589  1549    1389
# 1        01bf5a06-4248-43a5-9524-56123fa3ab2f  1569  1529    1369
# 2        01bf5a06-4248-43a5-9524-56123fa3ab2f  1569  1529    1359
# 3        01bf5a06-4248-43a5-9524-56123fa3ab2f  1539  1499    1339
# 4        01bf5a06-4248-43a5-9524-56123fa3ab2f  1529  1489    1329
# 5        01bf5a06-4248-43a5-9524-56123fa3ab2f  1629  1589    1429
# 6        01bf5a06-4248-43a5-9524-56123fa3ab2f  1549  1509    1389
# 7        01bf5a06-4248-43a5-9524-56123fa3ab2f  1549  1509    1379
# 8        01bf5a06-4248-43a5-9524-56123fa3ab2f  1549  1509    1339
# 9        01bf5a06-4248-43a5-9524-56123fa3ab2f  1559  1519    1309
# 10       01bf5a06-4248-43a5-9524-56123fa3ab2f  1559  1519    1299
# 11       01bf5a06-4248-43a5-9524-56123fa3ab2f  1529  1489    1299
# 12       01bf5a06-4248-43a5-9524-56123fa3ab2f  1619  1579    1419
# 13       01bf5a06-4248-43a5-9524-56123fa3ab2f  1569  1529    1369
# 14       01bf5a06-4248-43a5-9524-56123fa3ab2f  1619  1579    1419
# 15       01bf5a06-4248-43a5-9524-56123fa3ab2f  1509  1469    1309
# 16       01bf5a06-4248-43a5-9524-56123fa3ab2f  1519  1479    1309
# 17       01bf5a06-4248-43a5-9524-56123fa3ab2f  1509  1469    1309
# 18       01bf5a06-4248-43a5-9524-56123fa3ab2f  1499  1459    1309
# 19       01bf5a06-4248-43a5-9524-56123fa3ab2f  1489  1449    1299
# 20       01bf5a06-4248-43a5-9524-56123fa3ab2f  1479  1439    1289
# 21       01bf5a06-4248-43a5-9524-56123fa3ab2f  1559  1519    1359
# 22       01bf5a06-4248-43a5-9524-56123fa3ab2f  1509  1469    1329
# 23       01bf5a06-4248-43a5-9524-56123fa3ab2f  1499  1459    1319
# 24       01bf5a06-4248-43a5-9524-56123fa3ab2f  1469  1429    1289
# 25       01bf5a06-4248-43a5-9524-56123fa3ab2f  1459  1419    1279
# 26       01bf5a06-4248-43a5-9524-56123fa3ab2f  1449  1409    1279
# 27       01bf5a06-4248-43a5-9524-56123fa3ab2f  1439  1399    1269
# 28       01bf5a06-4248-43a5-9524-56123fa3ab2f  1429  1389    1259
# 29       01bf5a06-4248-43a5-9524-56123fa3ab2f  1579  1539    1399
# ...                                       ...   ...   ...     ...
# 2177817  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1289  1269    1109
# 2177818  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1289  1269    1139
# 2177819  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1289  1269    1119
# 2177820  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1279  1259    1109
# 2177821  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1269  1249    1129
# 2177822  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1259  1239    1119
# 2177823  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1409  1389    1269
# 2177824  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1389  1369    1229
# 2177825  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1359  1339    1219
# 2177826  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1349  1329    1209
# 2177827  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1309  1289    1159
# 2177828  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1289  1269    1139
# 2177829  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1299  1279    1149
# 2177830  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1279  1259    1129
# 2177831  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1269  1249    1119
# 2177832  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1409  1389    1239
# 2177833  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1399  1379    1239
# 2177834  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1409  1389    1269
# 2177835  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1399  1379    1239
# 2177836  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1349  1329    1239
# 2177837  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1349  1329    1179
# 2177838  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1339  1319    1179
# 2177839  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1359  1339    1189
# 2177840  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1349  1329    1189
# 2177841  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1349  1329    1179
# 2177842  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1629  1589    1429
# 2177843  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1689  1649    1489
# 2177844  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1629  1589    1419
# 2177845  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1619  1579    1419
# 2177846  4d9c944e-9e75-4bb9-8041-0ae354774d9f  1619  1579    1409
#
#                        DATE_CHANGED  CHANGED
# 0        2014-10-02 05:22:01.000000       21
# 1        2014-10-02 05:26:01.000000       21
# 2        2014-10-02 09:06:01.000000        1
# 3        2014-10-03 12:14:01.000000       21
# 4        2014-10-03 14:14:01.000000       21
# 5        2014-10-04 23:10:01.000000       21
# 6        2014-10-06 06:02:01.000000       20
# 7        2014-10-06 07:38:01.000000        1
# 8        2014-10-06 08:26:01.000000        1
# 9        2014-10-07 07:38:01.000000        1
# 10       2014-10-07 10:18:01.000000        1
# 11       2014-10-07 10:22:01.000000       20
# 12       2014-10-10 23:10:01.000000       21
# 13       2014-10-11 06:22:02.000000       21
# 14       2014-10-11 23:10:01.000000       21
# 15       2014-10-13 11:34:01.000000       21
# 16       2014-10-14 12:14:01.000000       21
# 17       2014-10-14 12:18:01.000000       20
# 18       2014-10-15 14:10:01.000000       21
# 19       2014-10-15 14:18:01.000000       21
# 20       2014-10-15 14:46:01.000000       21
# 21       2014-10-17 23:06:01.000000       21
# 22       2014-10-19 09:46:01.000000       21
# 23       2014-10-19 09:50:01.000000       21
# 24       2014-10-20 12:18:01.000000       21
# 25       2014-10-20 13:10:01.000000       21
# 26       2014-10-20 14:14:01.000000       20
# 27       2014-10-21 14:18:01.000000       21
# 28       2014-10-21 18:14:01.000000       21
# 29       2014-10-23 23:10:01.000000       21
# ...                             ...      ...
# 2177817  2015-02-03 08:26:01.000000       21
# 2177818  2015-02-04 08:30:01.000000       21
# 2177819  2015-02-04 10:14:01.000000        1
# 2177820  2015-02-04 10:18:01.000000       21
# 2177821  2015-02-05 15:26:01.000000       21
# 2177822  2015-02-06 14:34:01.000000       21
# 2177823  2015-02-07 21:10:01.000000       21
# 2177824  2015-02-09 06:22:01.000000       21
# 2177825  2015-02-09 06:26:01.000000       21
# 2177826  2015-02-09 08:58:01.000000       21
# 2177827  2015-02-10 08:54:01.000000       21
# 2177828  2015-02-10 10:18:01.000000       21
# 2177829  2015-02-11 10:22:01.000000       21
# 2177830  2015-02-12 10:22:01.000000       21
# 2177831  2015-02-12 13:22:02.000000       21
# 2177832  2015-02-16 06:22:01.000000       21
# 2177833  2015-02-16 07:38:01.000000       20
# 2177834  2015-02-17 06:22:01.000000       21
# 2177835  2015-02-17 06:26:01.000000       21
# 2177836  2015-02-17 08:22:01.000000       20
# 2177837  2015-02-17 08:30:01.000000        1
# 2177838  2015-02-17 09:18:01.000000       20
# 2177839  2015-02-18 08:22:01.000000       21
# 2177840  2015-02-18 09:18:01.000000       20
# 2177841  2015-02-18 10:30:01.000000        1
# 2177842  2014-07-03 15:10:01.000000       21
# 2177843  2014-07-03 17:10:01.000000       21
# 2177844  2014-07-05 03:14:01.000000       21
# 2177845  2014-07-05 03:18:01.000000       20
# 2177846  2014-07-05 03:30:01.000000        1
#
# [1094763 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
prices.plot(x="DATE_CHANGED", y= "E5")
plt.show()

# %%
station.head()
# Out:
#                                      ID  VERSION                VERSION_TIME  \
# 0  d37bee76-91b6-485a-b974-24f1b0d391fa        4  2015-01-09 10:26:15.000000
# 1  51d4b652-a095-1aa0-e100-80009459e03a      796  2015-09-28 21:00:13.000000
# 2  c7caf231-0e47-40db-92de-9349a2eb2bef        4  2014-09-26 13:24:57.000000
# 3  51d4b53b-a095-1aa0-e100-80009459e03a      796  2015-09-28 21:00:13.000000
# 4  51d4b70f-a095-1aa0-e100-80009459e03a      796  2015-09-28 21:00:13.000000
#
#                                     NAME BRAND                  STREET  \
# 0                        Aral Tankstelle  ARAL         An der Tagweide
# 1    JET MANNHEIM UNTERMUEHLAUSTRASSE 83   JET  UNTERMUEHLAUSTRASSE 83
# 2                        Aral Tankstelle  ARAL     Trippstadter Straße
# 3    JET KAISERSLAUTERN PARISER STR. 167   JET        PARISER STR. 167
# 4  JET GERMERSHEIM MUENCHENER STRASSE 12   JET   MUENCHENER STRASSE 12
#
#   HOUSE_NUMBER POST_CODE           PLACE PUBLIC_HOLIDAY_IDENTIFIER        LAT  \
# 0            2     76139       Karlsruhe                        \N  49.020280
# 1           \N     68169        MANNHEIM                        \N  49.508962
# 2           69     67663  Kaiserslautern                        \N  49.433754
# 3           \N     67655  KAISERSLAUTERN                        \N  49.442200
# 4           \N     76726     GERMERSHEIM                        \N  49.226800
#
#         LNG
# 0  8.459429
# 1  8.467691
# 2  7.757465
# 3  7.748360
# 4  8.374400

# %%
station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 12 columns):
# ID                           824 non-null object
# VERSION                      824 non-null int64
# VERSION_TIME                 824 non-null object
# NAME                         824 non-null object
# BRAND                        802 non-null object
# STREET                       820 non-null object
# HOUSE_NUMBER                 674 non-null object
# POST_CODE                    820 non-null object
# PLACE                        820 non-null object
# PUBLIC_HOLIDAY_IDENTIFIER    824 non-null object
# LAT                          824 non-null float64
# LNG                          824 non-null float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 77.3+ KB

# %%
station['PLACE'].nunique()
# Out:
# 198

# %%
station['BRAND'].nunique()
# Out:
# 55

# %%
combined_Data = pd.merge(prices, station, left_on = 'STID', right_on = 'ID')

# %%
combine_place = combined_Data.groupby(['PLACE'])['CHANGED'].sum().sort_values( ascending=False)
print (combine_place)
# Out:
# PLACE
# Karlsruhe                  2863940
# Ludwigshafen               1712122
# Mannheim                   1587644
# Kaiserslautern             1302954
# KARLSRUHE                  1227764
# MANNHEIM                    946830
# LUDWIGSHAFEN                910176
# Worms                       850204
# Speyer                      751320
# KAISERSLAUTERN              723284
# WORMS                       671366
# RASTATT                     661582
# FRANKENTHAL                 591666
# PIRMASENS                   541724
# Ettlingen                   514308
# LANDAU                      491456
# Neustadt                    490556
# Pirmasens                   480664
# WOERTH                      463068
# Gernsheim                   426554
# HASSLOCH                    419724
# Landau                      379744
# Edenkoben                   379512
# Phillipsburg                374900
# Lampertheim                 349724
# MUTTERSTADT                 342678
# Schifferstadt               339320
# Rastatt                     338924
# GERMERSHEIM                 322140
# RAMSTEIN                    293450
#                             ...
# Dannstadt-Schauernhe         70588
# Waldfischbach-Burgalben      70086
# KIRCHHEIM                    68194
# Ludwigshafen-Oggersheim      67898
# Limburgerhof                 67654
# Gundersheim                  59918
# Edesheim                     58628
# GRUENSTADT                   58388
# Freckenfeld                  57094
# Hauenstein                   50492
# Dannstadt                    47260
# Maxdorf                      47178
# Joehlingen                   45640
# Flörsheim-Dalsheim           41908
# Iffezheim                    41232
# Sien                         38594
# Dahn                         35222
# Mahlberg / Baden             31516
# Bobenheim-Roxheim            25222
# Queidersbach                 24684
# Bann                         11692
# RAMSTEIN-MIESENBACH           8562
# Kröppen                       8310
# \N                            7756
# Eich                          6214
# Wattenheim                    4278
# Katzenbach                    3790
# Westhofen                     3318
# Ötigheim                      3152
# mehr aktiv                     672
# Name: CHANGED, Length: 198, dtype: int64

# %%
station.groupby('PLACE')['BRAND'].nunique()
# Out:
# PLACE
# ALZEY                       2
# ANNWEILER                   2
# Altrip                      1
# Alzey                       1
# Annweiler-Queichhambach     1
# Au am Rhein                 1
# BAD BERGZABERN              1
# BAD DUERKHEIM               1
# BIBLIS                      1
# Bad Bergzabern              1
# Bad Duerkheim               1
# Bad Dürkheim                2
# Bad Herrenalb               1
# Bad Sobernheim              2
# Baden-Baden                 1
# Bann                        1
# Bellheim                    2
# Biblis                      1
# Bietigheim                  2
# Birkenheide                 1
# Bobenheim-Roxheim           0
# Bockenheim                  1
# BÖHL-IGGELHEIM              1
# Bürstadt                    4
# Carlsberg                   1
# DAHN                        1
# DIRMSTEIN                   1
# DUDENHOFEN                  1
# DURMERSHEIM                 1
# Dahn                        0
#                            ..
# Rülzheim                    1
# SCHWEGENHEIM                1
# SPEYER                      3
# Saalstadt                   1
# Schifferstadt               4
# Sien                        1
# Speyer                      4
# Standenbühl                 1
# Steinweiler                 1
# Stutensee                   1
# Stutensee-Blankenloch       1
# Thaleischweiler-Fröschen    1
# Vinningen                   1
# WALDBRONN                   1
# WARTENBERG-ROHRBACH         1
# WINNWEILER                  1
# WOERTH                      3
# WORMS                       3
# Wachenheim                  2
# Waldbronn                   1
# Waldfischbach-Burgalben     2
# Waldsee                     1
# Wattenheim                  1
# Weilerbach                  2
# Westhofen                   1
# Worms                       5
# Worms-Pfeddersheim          1
# \N                          1
# mehr aktiv                  1
# Ötigheim                    1
# Name: BRAND, Length: 198, dtype: int64

# %%
ax = combine_place.plot.bar(x='PLACE', y='CHANGED', rot=0)

# %%
get_ipython().magic('matplotlib inline')
station.groupby('PLACE')['BRAND'].nunique().plot(kind='bar')

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 6 columns):
# STID            1048575 non-null object
# E5              1048575 non-null int64
# E10             1048575 non-null int64
# DIESEL          1048575 non-null int64
# DATE_CHANGED    1048575 non-null object
# CHANGED         1048575 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 48.0+ MB

# %%
prices.head()
# Out:
#                                    STID    E5   E10  DIESEL  \
# 0  01bf5a06-4248-43a5-9524-56123fa3ab2f  1589  1549    1389
# 1  01bf5a06-4248-43a5-9524-56123fa3ab2f  1569  1529    1369
# 2  01bf5a06-4248-43a5-9524-56123fa3ab2f  1569  1529    1359
# 3  01bf5a06-4248-43a5-9524-56123fa3ab2f  1539  1499    1339
# 4  01bf5a06-4248-43a5-9524-56123fa3ab2f  1529  1489    1329
#
#                  DATE_CHANGED  CHANGED
# 0  2014-10-02 05:22:01.000000       21
# 1  2014-10-02 05:26:01.000000       21
# 2  2014-10-02 09:06:01.000000        1
# 3  2014-10-03 12:14:01.000000       21
# 4  2014-10-03 14:14:01.000000       21

# %%
prices[['DATE_CHANGED','E5']].set_index('DATE_CHANGED').plot(color="green", linewidth=1.0)
import matplotlib.pyplot as plt
prices.plot(x="E5", y= "E10")
plt.show()

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094763 entries, 0 to 2177846
# Data columns (total 6 columns):
# STID            1094763 non-null object
# E5              1094763 non-null int64
# E10             1094763 non-null int64
# DIESEL          1094763 non-null int64
# DATE_CHANGED    1094763 non-null object
# CHANGED         1094763 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 58.5+ MB
